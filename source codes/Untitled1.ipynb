# %%
import numpy as np

# %%
a = np.array([[1,2,3],[2,3,4]])
b = np.array([[0,1,2],[2,3,4]])
a + b
# Out:
# array([[1, 3, 5],
#        [4, 6, 8]])

# %%
import matplotlib.pyplot as plt

# %%
x = np.arange(0,10)
y = np.arange(2,12)
plt.plot(x, y)
